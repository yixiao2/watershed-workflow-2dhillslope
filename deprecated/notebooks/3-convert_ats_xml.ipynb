# %% [markdown]
# # convert xml for specific ATS branch
# - this workflow is based on Watershed-Workflow 1.5 and ATS 1.5
# - in order to use the ATS from Phong's branch or the latest ATS 1.6, need to convert all xml files for ATS-flow and ATS-PFLTORAN simulations

# %% [markdown]
# ## for ATS-flow run0/1/2

# %%
import os
import sys
from pathlib import Path
import subprocess

# Remove old amanzi_xml path if it exists
old_amanzi_path = '/home/xiao284/softwares/ats-15-25jan/repos/amanzi/tools/amanzi_xml'
if old_amanzi_path in sys.path:
    sys.path.remove(old_amanzi_path)

# Add new amanzi_xml path at the beginning (highest priority)
new_amanzi_path = '/home/xiao284/softwares/ats-master-251124/repos/amanzi/tools/amanzi_xml'
## phong's branch uses Path('/home/xiao284/softwares/ats-15-25sep-phong/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-master.py')
sys.path.insert(0, str(new_amanzi_path))

# Verify the change
import amanzi_xml
print(f"Using amanzi_xml from: {amanzi_xml.__file__}")

# %%
base_dir = Path().resolve().parent  # Assumes the notebook is inside the notebooks/ directory

xmlinputconvert_path = Path('/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters')

# Create a clean environment and set only the new PYTHONPATH
env = os.environ.copy()
new_pythonpath = '/home/xiao284/softwares/ats-master-251124/repos/amanzi/tools/amanzi_xml'
# REPLACE (not append) the PYTHONPATH to ensure old path isn't used
env['PYTHONPATH'] = new_pythonpath

# %%
## caseflow-run0
tmp_xml = base_dir / 'caseflow-run0' / 'NF01_nx100_nz18.run0.v1.5.xml'
tmp_xml_o = base_dir / 'caseflow-run0' / 'NF01_nx100_nz18.run0.v1.6.xml'
command = f"python {xmlinputconvert_path / 'xml-1.5-1.6.py'} {tmp_xml} -o {tmp_xml_o}"
try:
    result = subprocess.run(command, shell=True, check=True, env=env, 
                          capture_output=True, text=True)
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")

## caseflow-run1
tmp_xml = base_dir / 'caseflow-run1' / 'NF01_nx100_nz18.run1.v1.5.xml'
tmp_xml_o = base_dir / 'caseflow-run1' / 'NF01_nx100_nz18.run1.v1.6.xml'
command = f"python {xmlinputconvert_path / 'xml-1.5-1.6.py'} {tmp_xml} -o {tmp_xml_o}"
try:
    result = subprocess.run(command, shell=True, check=True, env=env, 
                          capture_output=True, text=True)
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")

## caseflow-run2
tmp_xml = base_dir / 'caseflow-run2' / 'NF01_nx100_nz18.run2.v1.5.xml'
tmp_xml_o = base_dir / 'caseflow-run2' / 'NF01_nx100_nz18.run2.v1.6.xml'
command = f"python {xmlinputconvert_path / 'xml-1.5-1.6.py'} {tmp_xml} -o {tmp_xml_o}"
try:
    result = subprocess.run(command, shell=True, check=True, env=env, 
                          capture_output=True, text=True)
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")

# %% [markdown]
# ## for ATS-PFLTORAN
# - noticing that the boundary mass flux observation part is not included
# - for ATS-1.6
#     - first, run the workflow to obtain ATS-PFLOTRAN xml for ATS-1.5.
#     - second, run this convert notebook to obtain ATS-PFLTORAN xml for ATS-1.6
#     - third, run `3-configure_obs_for_boundary_mass_flux.ipynb` to add observation for boundary mass flux calculation.

# %%
## casecybernetic-run1.s1
flag_scenario = 's1'

tmp_xml = base_dir / f'casecybernetic-run1.{flag_scenario}' / 'NF01_nx100_nz18.run1.v1.5_pflotran.xml'
tmp_xml_o = base_dir / f'casecybernetic-run1.{flag_scenario}' / 'NF01_nx100_nz18.run1.v1.6_pflotran.xml'
command = f"python {xmlinputconvert_path / 'xml-1.5-1.6.py'} {tmp_xml} -o {tmp_xml_o}"
try:
    result = subprocess.run(command, shell=True, check=True, env=env, 
                          capture_output=True, text=True)
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")

# %% [raw]
# # Error message if run the python command in terminal
# # need to source set_ats_env/ats-master.wsl.251124.sh
#
# (watershed_workflow_1.5) xiao284@WE49363:~/projects/OakCreek/test_OakCreek_ATS_2D_cleaned/casecybernetic-run1.s1$ python /home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py NF01_nx100_nz18.run1.v1.5_pflotran.xml -o NF01_nx100_nz18.run1.v1.6_pflotran.xml                                                                                            Converting file: NF01_nx100_nz18.run1.v1.5_pflotran.xml
# fixing transport pk
# found MD for names: []
# searching for LWC = water_content
# Traceback (most recent call last):
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py", line 693, in <module>
#     update(xml)
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py", line 657, in update
#     fixTransportPKs(xml)
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py", line 635, in fixTransportPKs
#     fixTransportPK(pk_list.sublist(pk.getName()), evals_list)
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py", line 621, in fixTransportPK
#     fixTransportPK_Source(pk, evals_list, domain, components)
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py", line 375, in fixTransportPK_Source
#     res = _fixTransportPK_OneSource(source_term, pk, evals_list, domain,
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py", line 343, in _fixTransportPK_OneSource
#     ret = _createTransportSource_Simple(source_term, new_source, kwargs["components"], model)
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/src/physics/ats/tools/input_converters/xml-1.5-1.6.py", line 261, in _createTransportSource_Simple
#     asearch.find_path(out_source_entry, ["number of dofs",]).setValue(len(components))
#   File "/home/xiao284/softwares/ats-master-251124/repos/amanzi/tools/amanzi_xml/amanzi_xml/utils/search.py", line 158, in find_path
#     raise errors.MissingXMLError("Object does not have path '{}'".format(names))
# amanzi_xml.utils.errors.MissingXMLError: Object does not have path '['number of dofs']'
